# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To load the dataset
df=pd.read_csv("C:/Users/INTERFACE/OneDrive/Desktop/ENTRI ASSIGNMENT/PYTHON/myexcel - myexcel.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#To correct the data in the "height" column by replacing it with random numbers between 150 and 180.
df['Height'] = np.random.randint(150, 181, size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     154     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     175     235
# 2     John Holland  Boston Celtics      30       SG   27     155     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     160     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     154     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     173     256
# 456    Jeff Withey       Utah Jazz      24        C   26     169     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#To ensure data consistency and integrity 
df.drop_duplicates(inplace=True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 34.0+ KB
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     154     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     175     235
# 2   John Holland  Boston Celtics      30       SG   27     155     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     164     185
# ...

# %% [markdown]
# # Analysis Tasks

# %%
#1.Distribution of employees across each team with percentage
team_distribution = df['Team'].value_counts().reset_index()
team_distribution.columns = ['Team', 'Employee Count']
team_distribution['Percentage'] = (team_distribution['Employee Count'] / len(df)) * 100
print("Employee Distribution by Team:\n", team_distribution)
# Out:
# Employee Distribution by Team:
#                        Team  Employee Count  Percentage
# 0     New Orleans Pelicans              19    4.148472
# 1        Memphis Grizzlies              18    3.930131
# 2                Utah Jazz              16    3.493450
# 3          New York Knicks              16    3.493450
# 4          Milwaukee Bucks              16    3.493450
# 5            Brooklyn Nets              15    3.275109
# 6   Portland Trail Blazers              15    3.275109
# 7    Oklahoma City Thunder              15    3.275109
# 8           Denver Nuggets              15    3.275109
# 9       Washington Wizards              15    3.275109
# 10              Miami Heat              15    3.275109
# 11       Charlotte Hornets              15    3.275109
# 12           Atlanta Hawks              15    3.275109
# 13       San Antonio Spurs              15    3.275109
# 14         Houston Rockets              15    3.275109
# ...

# %%
#2.Segregating employees by their positions
position_distribution = df['Position'].value_counts().reset_index()
position_distribution.columns = ['Position', 'Employee Count']
print("Employee Distribution by Position:\n", position_distribution)
# Out:
# Employee Distribution by Position:
#    Position  Employee Count
# 0       SG             102
# 1       PF             100
# 2       PG              92
# 3       SF              85
# 4        C              79

# %%
#3.Predominant age group
age= [18, 22, 25, 28, 31, 34, 40]
age_labels = ['18-22', '23-25', '26-28', '29-31', '32-34', '35-40']
df['Age Group'] = pd.cut(df['Age'], bins=age, labels=age_labels)
age_group_distribution = df['Age Group'].value_counts().sort_index()
print("Predominant Age Group:\n", age_group_distribution)
# Out:
# Predominant Age Group:
#  18-22     66
# 23-25    134
# 26-28    108
# 29-31     81
# 32-34     37
# 35-40     32
# Name: Age Group, dtype: int64

# %%
#4.Team and Position with Highest Salary Expenditure
salary_df = df.dropna(subset=['Salary'])
salary_summary = salary_df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
highest_salary = salary_summary.sort_values(by='Salary', ascending=False).head(1)
print("Team and Position with Highest Salary Expenditure:\n", highest_salary)
# Out:
# Team and Position with Highest Salary Expenditure:
#                    Team Position      Salary
# 67  Los Angeles Lakers       SF  31866445.0

# %%
# 5.Correlation between Age and Salary
corr_df = df.dropna(subset=['Salary'])
correlation = corr_df['Age'].corr(corr_df['Salary'])
print(f"Correlation Between Age and Salary: {correlation:.2f}")

#For visual representation
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Salary', data=corr_df, scatter_kws={'alpha':0.6})
plt.title('Correlation Between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.show()
# Out:
# Correlation Between Age and Salary: 0.21

# %% [markdown]
# # Graphical Representations

# %%
#1.Distribution of employees across each team with percentage 
plt.figure(figsize=(10, 6))
sns.barplot(y='Team', x='Employee Count', data=team_distribution.sort_values('Employee Count', ascending=False), palette='viridis')
plt.title('1. Employee Distribution by Team')
plt.xlabel('Number of Employees')
plt.ylabel('Team')
plt.show()

# %%
#2.Segregate employees by their positions
plt.figure(figsize=(10, 6))
plt.pie(position_distribution['Employee Count'], labels=position_distribution['Position'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2"))
plt.title('2. Employee Distribution by Position')
plt.axis('equal')
plt.show()

# %%
#3.Predominant age group
plt.figure(figsize=(10, 6))
sns.barplot(x=age_group_distribution.index, y=age_group_distribution.values, palette='muted')
plt.title('3. Employee Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()

# %%
# 4.Team and Position with Highest Salary Expenditure
plt.figure(figsize=(12, 6))
sns.barplot(x='Salary', y=highest_salary['Team'] + ' - ' + highest_salary['Position'], data=highest_salary, palette='rocket')
plt.title('4. Top 10 Salary Expenditures by Team & Position')
plt.xlabel('Total Salary')
plt.ylabel('Team - Position')
plt.show()

# %%
#5.Correlation between Age and Salary
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Salary', data=corr_df, scatter_kws={'alpha':0.6}, line_kws={'color': 'red'})
plt.title('5. Correlation Between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Data Story

# %% [markdown]
# The analysis of the employee dataset reveals several notable trends and insights.Team sizes throughout the league are fairly uniform, with most teams having between 15 players, although some like the New Orleans Pelicans and Memphis Grizzlies are slightly above this, likely for extra reserve or development players.Role-wise, shooting guards (SG), power forwards (PF), and point guards (PG) are most typical, symbolizing the emphasis of the modern game on flexibility, adaptability, and periphery play.Age-wise,the majority of players fall within the 23–28 range,correlating with professional athletes common peak performance ages.When it comes to salary expenditure, certain team-position combinations most notably small forwards (SF) on the Cleveland Cavaliers command the highest total compensation, indicating that teams strategically invest in key roles or star talent.Notably, the relationship between age and salary is weakly positive,which implies that while experience plays some role in earning power,performance,position and market worth are much greater determinants. Overall,the data paints a picture of a performance-driven league that prioritizes talent,role specialization and strategic financial investment over simple seniority.
#
#
#
# Major insights gained from the analysis are:
#
# 1.Most teams maintain standard roster sizes, suggesting uniformity in squad planning across the league.
#
# 2.There’s a trend toward guard-heavy lineups, reflecting the league’s shift toward faster-paced, perimeter-oriented playstyles.
#
# 3.Most players are in their athletic prime — not too young, not past their peak. This aligns with performance expectations in     professional basketball.
#
# 4.Salary distribution is not even,teams invest more in certain positions based on star power,performance, or strategic value.
#
# 5.While experience (age) might slightly influence salary, it's not the main factor. Young, high-performing players may earn       more than older, average players.
